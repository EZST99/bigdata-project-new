# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# In this notebook, we analyze audience sentiment based on YouTube comments that were previously collected and stored in HBase. Using a rule-based sentiment analyzer, we assign sentiment scores to individual comments, aggregate them per trailer, and finally combine the results with the trailer-movie join data. The resulting dataset serves as the basis for later visualization and interpretation.

# %% [markdown]
# ### Loading required libraries
#
# This cell imports the libraries needed for sentiment analysis and data handling.
# VADER is used to compute sentiment scores for comment texts, while pandas is used for structuring and aggregating the data.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import happybase
import pandas as pd
from collections import defaultdict

# %% [markdown]
# ### Initializing the sentiment analyzer
#
# Here, the VADER sentiment analyzer is initialized. This object will later be used to compute sentiment scores for each YouTube comment.

# %%
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Connecting to HBase and accessing comments
#
# In this step, a connection to HBase is established and the `kinocheck_comments` table is accessed. This table contains all previously stored YouTube comments together with their metadata.

# %%
conn = happybase.Connection(host="hbase", port=9090, timeout=20000)
conn.open()
comments_table = conn.table("kinocheck_comments")

# %% [markdown]
# ### Computing sentiment scores for comments
#
# This cell scans the comments table and processes each comment individually.
# For every comment, the sentiment score is calculated using VADER’s compound score. The result is stored together with the corresponding video ID, creating a list of sentiment-scored comments.

# %%
rows = []

for _, data in comments_table.scan(columns=[b"yt:video_id", b"yt:text"]):
    video_id = data[b"yt:video_id"].decode()
    text = data[b"yt:text"].decode(errors="ignore")

    score = analyzer.polarity_scores(text)["compound"]

    rows.append({
        "video_id": video_id,
        "sentiment": score
    })

# %% [markdown]
# ## Creating a DataFrame of comment sentiment
#
# The collected sentiment data is converted into a pandas DataFrame.  Afterwards, the scores are aggregated per trailer video. For each video, the average sentiment is calculated, along with the proportions of positive, neutral, and negative comments. This step summarizes individual reactions into a single sentiment profile per trailer.

# %%
df_comments = pd.DataFrame(rows)

# %%
agg = df_comments.groupby("video_id").agg(
    comment_count=("sentiment", "count"),
    sentiment_mean=("sentiment", "mean"),
    sentiment_median=("sentiment", "median"),
    sentiment_std=("sentiment", "std"),
    positive_ratio=("sentiment", lambda x: (x > 0.05).mean()),
    negative_ratio=("sentiment", lambda x: (x < -0.05).mean()),
)

# %% [markdown]
# ### Reading the trailer-movie join table
#
# Here we define a helper function that reads the trailer-movie join data from HBase. The function extracts relevant movie metadata, such as title, year, rating, revenue, and success label, and returns it in a structured format.

# %%
import happybase

def read_join_table():
    rows = []

    conn = happybase.Connection(
        host="hbase",
        port=9090,
        timeout=60000   # wichtig
    )
    conn.open()

    try:
        table = conn.table("trailer_movie_join")

        for rk, data in table.scan(
            columns=[
                b"cf:rating",
                b"cf:revenue",
                b"cf:success"
            ],
            batch_size=100,        # wichtig!
            scan_batching=50       # sehr wichtig!
        ):
            try:
                rows.append({
                    "video_id": rk.decode(),
                    "rating": float(data[b"cf:rating"].decode()),
                    "revenue": float(data[b"cf:revenue"].decode()) if data.get(b"cf:revenue") else None,
                    "success": int(float(data[b"cf:success"].decode()))
                })
            except Exception:
                continue

    finally:
        conn.close()

    return rows

# %% [markdown]
# ### Loading join data into a DataFrame and mergin
#
#
# The join table data is loaded into a pandas DataFra The aggregated sentiment data is merged with the trailer–movie join data using the video ID. The result is a unified dataset that links audience sentiment with movie success indicators.-related information for merging with the sentiment results.

# %%
join_rows = read_join_table()
len(join_rows)
# Out:
# 249

# %%
df_join = pd.DataFrame(join_rows)

final_df = agg.reset_index().merge(
    df_join,
    on="video_id",
    how="inner"
)

# %% [markdown]
# ### Closing the HBase connection and saving the final analysis dataset
# After all required data has been loaded and merged, the connection to HBase is closed.
# Finally, the merged dataset is saved as a CSV file. This file is used as the input for the subsequent visualization and interpretation notebook.

# %%
conn.close()

# %%
final_df.to_csv("../data/final_analysis_dataset.csv", index=False)
