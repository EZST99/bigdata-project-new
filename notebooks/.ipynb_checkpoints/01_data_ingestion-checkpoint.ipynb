# %% [markdown]
# # Data Ingestion

# %% [markdown]
# In this notebook, we take the raw movie dataset from a CSV file and store it in HBase.
# This is the first step of our data pipeline and serves as the*raw data laye* that later notebooks will build on using Spark.

# %% [markdown]
# ### Installing dependencies and importing libraries
# In this notebook we ingest our raw movie dataset into HBase.
# To connect to HBase from Python, we use HappyBase, which communicates with HBase through the Thrift interface (running in docker).
# - **pandas**: to load and iterate over the CSV file
# - **happybase**: connect to HBase and write data into a table

# %%
# !pip install happybase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import happybase

# %% [markdown]
# ### Load source data
# We first load the dataset from a CSV file into a pandas DataFrame.
# This gives us a structured in-memory table that we can validate and then ingest into HBase.

# %%
df = pd.read_csv("/home/jovyan/data/movie_success_rate.csv")

# %% [markdown]
# ### Connect to HBase
# Afterwards, we connect to HBase.
#
# **Table design**
# - Table name: `movie_success_rate_raw`
# - Column family: `cf` (we keep all columns under one family for simplicity)
# - This table represents the raw ingestion layer.

# %%
conn = happybase.Connection(
    host="hbase",
    port=9090,
    timeout=20000
)
conn.open()

if b'movie_success_rate_raw' not in conn.tables():
    conn.create_table(
        'movie_success_rate_raw',
        {'cf': dict()}
    )

table = conn.table('movie_success_rate_raw')

# %% [markdown]
# ### Writing the data into HBase
#
# The data is written to HBase in chunks instead of all at once.
# This keeps memory usage low and improves write performance.
#
# For each row:
# - We generate a unique row key using the movie title, year, and index
# - Each column is stored as a separate qualifier under the `cf` column family
# - Rows without a title are skipped to avoid invalid keys
#
# Batch writes are used to reduce the number of network calls to HBase.

# %%
CHUNK_SIZE = 100

for start in range(0, len(df), CHUNK_SIZE):
    end = start + CHUNK_SIZE
    chunk = df.iloc[start:end]

    batch = table.batch() 

    for idx, row in chunk.iterrows():
        if pd.isna(row["Title"]):
            continue

        rowkey = f"{row['Title']}_{row['Year']}_{idx}".encode()

        batch.put(rowkey, {
            b'cf:title': str(row['Title']).encode(),
            b'cf:year': str(row['Year']).encode(),
            b'cf:rating': str(row['Rating']).encode(),
            b'cf:votes': str(row['Votes']).encode(),
            b'cf:revenue': str(row['Revenue (Millions)']).encode(),
            b'cf:metascore': str(row['Metascore']).encode(),
            b'cf:success': str(row['Success']).encode(),
        })

    batch.send()
    print(f"Inserted rows {start} to {end}")
# Out:
# Inserted rows 0 to 100
# Inserted rows 100 to 200
# Inserted rows 200 to 300
# Inserted rows 300 to 400
# Inserted rows 400 to 500
# Inserted rows 500 to 600
# Inserted rows 600 to 700
# Inserted rows 700 to 800
# Inserted rows 800 to 900

# %%
# Verify the ingestion
sample = []
for i, (key, data) in enumerate(table.scan(limit=5)):
    row = {k.decode(): v.decode() for k, v in data.items()}
    row["rowkey"] = key.decode()
    sample.append(row)

pd.DataFrame(sample)
# Out:
#   cf:metascore cf:rating cf:revenue cf:success              cf:title  \
# 0         76.0       7.7      32.39        0.0  (500) Days of Summer
# 1         76.0       7.2       71.9        0.0   10 Cloverfield Lane
# 2         96.0       8.1      56.67        0.0      12 Years a Slave
# 3         82.0       7.6      18.33        0.0             127 Hours
# 4         48.0       7.3      52.82        0.0              13 Hours
#
#    cf:votes cf:year                           rowkey
# 0  398972.0  2009.0  (500) Days of Summer_2009.0_443
# 1  192968.0  2016.0   10 Cloverfield Lane_2016.0_103
# 2  486338.0  2013.0       12 Years a Slave_2013.0_98
# 3  294010.0  2010.0             127 Hours_2010.0_698
# 4   76935.0  2016.0              13 Hours_2016.0_149
